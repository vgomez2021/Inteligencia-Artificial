# %% [markdown]
# <a href="https://colab.research.google.com/github/vgomez2021/Inteligencia-Artificial/blob/main/Ejercicio%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Importar el archivo CSV
df = pd.read_csv('nba.csv')  # Reemplaza 'tu_archivo.csv' con el nombre de tu archivo

# 2. Modificar el campo nombre por jugador
df = df.rename(columns={'nombre': 'jugador'})

# 3. Imprimir el dataframe (opcional, para verificar)
print(df)

# 4. Menú de opciones para el usuario
while True:
    print("\n¿Qué deseas hacer?")
    print("1. Ver todos los jugadores")
    print("2. Ver detalle por jugador")
    print("3. Ver el puntaje general")
    print("4. Graficar")
    print("5. Salir")

    opcion = input("Ingresa el número de la opción: ")

    if opcion == '1':
        print("Nombres de los jugadores:")
        print(df['jugador'])
    elif opcion == '2':
        nombre_jugador = input("Ingrese el nombre del jugador: ")
        jugador = df[df['jugador'] == nombre_jugador]
        print(jugador)
    elif opcion == '3':
        puntaje_promedio = df['puntos'].mean()
        print("El puntaje promedio es:", puntaje_promedio)
    elif opcion == '4':
        plt.figure(figsize=(10, 10))
        plt.bar(df['jugador'], df['puntos'], color='green')
        plt.xlabel('Jugador')
        plt.ylabel('Puntos')
        plt.title('Puntos por jugador')
        plt.xticks(rotation=45)
        plt.show()
    elif opcion == '5':
        break
    else:
        print("Opción inválida. Intenta nuevamente.")
# Out:
#    pos      jugador  puntos
# 0    1        abdul   38387
# 1    2        james   36985
# 2    3       malone   36928
# 3    4       bryant   33600
# 4    5       jordan   32200
# 5    6     nowitski   31500
# 6    7  chamberlain   31400
# 7    8        onail   28500
# 8    9      anthony   28200
# 9   10       malone   27400
#
# ¿Qué deseas hacer?
# 1. Ver todos los jugadores
# 2. Ver detalle por jugador
# 3. Ver el puntaje general
# 4. Graficar
# 5. Salir
# Ingresa el número de la opción: 1
# Nombres de los jugadores:
# 0          abdul
# 1          james
# 2         malone
# 3         bryant
# 4         jordan
# 5       nowitski
# 6    chamberlain
# 7          onail
# 8        anthony
# 9         malone
# Name: jugador, dtype: object
#
# ¿Qué deseas hacer?
# 1. Ver todos los jugadores
# 2. Ver detalle por jugador
# 3. Ver el puntaje general
# 4. Graficar
# 5. Salir
# Ingresa el número de la opción: 3
# El puntaje promedio es: 32510.0
#
# ¿Qué deseas hacer?
# 1. Ver todos los jugadores
# 2. Ver detalle por jugador
# 3. Ver el puntaje general
# 4. Graficar
# 5. Salir
# Ingresa el número de la opción: 2
# Ingrese el nombre del jugador: malone
#    pos jugador  puntos
# 2    3  malone   36928
# 9   10  malone   27400
#
# ¿Qué deseas hacer?
# 1. Ver todos los jugadores
# 2. Ver detalle por jugador
# 3. Ver el puntaje general
# 4. Graficar
# 5. Salir
# Ingresa el número de la opción: 4
# ¿Qué deseas hacer?
# 1. Ver todos los jugadores
# 2. Ver detalle por jugador
# 3. Ver el puntaje general
# 4. Graficar
# 5. Salir
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-1b076dd93834> in <cell line: 14>()
#      20     print("5. Salir")
#      21
# ---> 22     opcion = input("Ingresa el número de la opción: ")
#      23
#      24     if opcion == '1':
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
